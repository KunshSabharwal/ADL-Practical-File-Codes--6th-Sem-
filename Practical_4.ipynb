# %% [markdown]
# # Boston Housing Dataset

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, r2_score
from tensorflow.keras.callbacks import EarlyStopping

(X_train, y_train), (X_test, y_test) = tf.keras.datasets.boston_housing.load_data()

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1)
])

model.compile(
    optimizer=Adam(learning_rate=0.002),
    loss='mse',
    metrics=['mae']
)

early_stop = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)

history = model.fit(
    X_train, y_train,
    epochs=300,
    batch_size=8,
    validation_split=0.1,
    verbose=1,
    callbacks=[early_stop]
)

y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("\nModel Evaluation:")
print("MSE:", mse)
print("R2 Score:", r2)
print("Model Accuracy (%):", r2 * 100)

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title("Loss vs Epochs")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['mae'], label='Train MAE')
plt.plot(history.history['val_mae'], label='Val MAE')
plt.title("MAE vs Epochs")
plt.xlabel("Epochs")
plt.ylabel("MAE")
plt.legend()
plt.show()
# Out:
# Epoch 1/300
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 520.7179 - mae: 20.5094 - val_loss: 145.4719 - val_mae: 10.5916
# Epoch 2/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 137.6308 - mae: 8.5989 - val_loss: 19.6829 - val_mae: 3.5973
# Epoch 3/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 30.7991 - mae: 3.7802 - val_loss: 16.0748 - val_mae: 3.1908
# Epoch 4/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 19.8876 - mae: 3.1937 - val_loss: 15.0338 - val_mae: 2.9774
# Epoch 5/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 17.7763 - mae: 2.8636 - val_loss: 13.3240 - val_mae: 2.7354
# Epoch 6/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 15.3753 - mae: 2.6821 - val_loss: 13.9188 - val_mae: 2.8172
# Epoch 7/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 14.5430 - mae: 2.7104 - val_loss: 11.8385 - val_mae: 2.6524
# Epoch 8/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 10.7402 - mae: 2.3884 - val_loss: 10.5867 - val_mae: 2.5015
# Epoch 9/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 10.4667 - mae: 2.3586 - val_loss: 11.7133 - val_mae: 2.8528
# Epoch 10/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 10.2713 - mae: 2.2429 - val_loss: 10.3009 - val_mae: 2.6687
# Epoch 11/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.6733 - mae: 2.2641 - val_loss: 10.1036 - val_mae: 2.6017
# Epoch 12/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6540 - mae: 2.2276 - val_loss: 8.9628 - val_mae: 2.3528
# Epoch 13/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.9267 - mae: 2.2219 - val_loss: 9.1486 - val_mae: 2.4406
# Epoch 14/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.7421 - mae: 2.2092 - val_loss: 8.4135 - val_mae: 2.3460
# Epoch 15/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.1218 - mae: 2.0807 - val_loss: 8.5491 - val_mae: 2.2453
# Epoch 16/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4166 - mae: 2.1162 - val_loss: 8.2707 - val_mae: 2.3128
# Epoch 17/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10.8509 - mae: 2.3327 - val_loss: 8.1270 - val_mae: 2.3110
# Epoch 18/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9451 - mae: 1.9852 - val_loss: 7.6251 - val_mae: 2.2942
# Epoch 19/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7847 - mae: 2.1325 - val_loss: 7.8212 - val_mae: 2.2842
# Epoch 20/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10.0464 - mae: 2.1190 - val_loss: 8.7303 - val_mae: 2.4165
# Epoch 21/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.9940 - mae: 2.2494 - val_loss: 7.1513 - val_mae: 2.0791
# Epoch 22/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.6392 - mae: 2.0014 - val_loss: 7.3033 - val_mae: 2.0974
# Epoch 23/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.3476 - mae: 2.0765 - val_loss: 6.8432 - val_mae: 2.1483
# Epoch 24/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3496 - mae: 1.9521 - val_loss: 7.0377 - val_mae: 2.1138
# Epoch 25/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.9916 - mae: 2.2173 - val_loss: 6.9246 - val_mae: 2.1591
# Epoch 26/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.9644 - mae: 2.0929 - val_loss: 7.3874 - val_mae: 2.3053
# Epoch 27/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8240 - mae: 1.9008 - val_loss: 7.4106 - val_mae: 2.1966
# Epoch 28/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5894 - mae: 1.9223 - val_loss: 6.8825 - val_mae: 2.1337
# Epoch 29/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6856 - mae: 1.7591 - val_loss: 6.7671 - val_mae: 2.1003
# Epoch 30/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.3930 - mae: 1.9187 - val_loss: 6.7057 - val_mae: 2.1958
# Epoch 31/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6284 - mae: 2.0714 - val_loss: 6.2493 - val_mae: 2.0709
# Epoch 32/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9097 - mae: 1.6288 - val_loss: 6.3640 - val_mae: 2.0491
# Epoch 33/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.5812 - mae: 2.0056 - val_loss: 6.8205 - val_mae: 2.2184
# Epoch 34/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8590 - mae: 1.9396 - val_loss: 6.8509 - val_mae: 2.1546
# Epoch 35/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.9824 - mae: 1.7846 - val_loss: 7.1964 - val_mae: 2.2130
# Epoch 36/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8516 - mae: 1.5993 - val_loss: 6.3068 - val_mae: 2.0910
# Epoch 37/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2553 - mae: 1.7828 - val_loss: 6.5628 - val_mae: 2.1007
# Epoch 38/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1504 - mae: 1.8538 - val_loss: 7.4121 - val_mae: 2.2506
# Epoch 39/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9994 - mae: 1.6123 - val_loss: 6.7117 - val_mae: 2.0463
# Epoch 40/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.4994 - mae: 2.0725 - val_loss: 8.4178 - val_mae: 2.4520
# Epoch 41/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7603 - mae: 1.7405 - val_loss: 6.5362 - val_mae: 2.1206
# Epoch 42/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6442 - mae: 1.7054 - val_loss: 6.4505 - val_mae: 2.1084
# Epoch 43/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1595 - mae: 1.5847 - val_loss: 7.1555 - val_mae: 2.2374
# Epoch 44/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8276 - mae: 1.7493 - val_loss: 6.4024 - val_mae: 2.1045
# Epoch 45/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3057 - mae: 1.6199 - val_loss: 5.8666 - val_mae: 2.0532
# Epoch 46/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2249 - mae: 1.7016 - val_loss: 6.4483 - val_mae: 2.1373
# Epoch 47/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.8812 - mae: 1.8040 - val_loss: 6.5097 - val_mae: 2.1139
# Epoch 48/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5724 - mae: 1.5993 - val_loss: 6.1695 - val_mae: 2.0974
# Epoch 49/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0840 - mae: 1.7776 - val_loss: 6.3430 - val_mae: 2.1023
# Epoch 50/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4188 - mae: 1.7667 - val_loss: 7.8074 - val_mae: 2.2900
# Epoch 51/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.3771 - mae: 1.8663 - val_loss: 7.5184 - val_mae: 2.2470
# Epoch 52/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6458 - mae: 1.4616 - val_loss: 6.6270 - val_mae: 2.1170
# Epoch 53/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1157 - mae: 1.4942 - val_loss: 8.5236 - val_mae: 2.3372
# Epoch 54/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6650 - mae: 1.6167 - val_loss: 6.6107 - val_mae: 2.0716
# Epoch 55/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.2779 - mae: 1.8404 - val_loss: 6.3222 - val_mae: 2.0344
# Epoch 56/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.9045 - mae: 1.7392 - val_loss: 6.4693 - val_mae: 2.0343
# Epoch 57/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.2395 - mae: 1.5619 - val_loss: 6.2522 - val_mae: 2.0563
# Epoch 58/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7520 - mae: 1.5230 - val_loss: 6.2006 - val_mae: 2.0322
# Epoch 59/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.6488 - mae: 1.5986 - val_loss: 5.9998 - val_mae: 1.9564
# Epoch 60/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4555 - mae: 1.5194 - val_loss: 6.7232 - val_mae: 2.0482
# Epoch 61/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2184 - mae: 1.6031 - val_loss: 6.1073 - val_mae: 2.0519
# Epoch 62/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1162 - mae: 1.6239 - val_loss: 6.8748 - val_mae: 2.0740
# Epoch 63/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2774 - mae: 1.4354 - val_loss: 6.2273 - val_mae: 2.0651
# Epoch 64/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1731 - mae: 1.8679 - val_loss: 6.5593 - val_mae: 2.0387
# Epoch 65/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0583 - mae: 1.5757 - val_loss: 6.3862 - val_mae: 2.0644
# Epoch 66/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5199 - mae: 1.4604 - val_loss: 6.2560 - val_mae: 2.0652
# Epoch 67/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0988 - mae: 1.4509 - val_loss: 7.5996 - val_mae: 2.2548
# Epoch 68/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9961 - mae: 1.7228 - val_loss: 6.1170 - val_mae: 1.9538
# Epoch 69/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7928 - mae: 1.4332 - val_loss: 6.0483 - val_mae: 1.9664
# Epoch 70/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3028 - mae: 1.5059 - val_loss: 7.1278 - val_mae: 2.1208
# Epoch 71/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8581 - mae: 1.4433 - val_loss: 6.2952 - val_mae: 1.9906
# Epoch 72/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5775 - mae: 1.5537 - val_loss: 6.4886 - val_mae: 2.0630
# Epoch 73/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7084 - mae: 1.4148 - val_loss: 5.9222 - val_mae: 2.0171
# Epoch 74/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6122 - mae: 1.5476 - val_loss: 5.9635 - val_mae: 1.9084
# Epoch 75/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6160 - mae: 1.6304 - val_loss: 5.9877 - val_mae: 1.9480
# Epoch 76/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3661 - mae: 1.4788 - val_loss: 6.0669 - val_mae: 1.9341
# Epoch 77/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3276 - mae: 1.4592 - val_loss: 6.9495 - val_mae: 2.0536
# Epoch 78/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8096 - mae: 1.5952 - val_loss: 6.0957 - val_mae: 2.0010
# Epoch 79/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1691 - mae: 1.4450 - val_loss: 6.2638 - val_mae: 1.9753
# Epoch 80/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1046 - mae: 1.4618 - val_loss: 7.0337 - val_mae: 2.0554
# Epoch 81/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1071 - mae: 1.4050 - val_loss: 5.8404 - val_mae: 1.8977
# Epoch 82/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8172 - mae: 1.4051 - val_loss: 6.3097 - val_mae: 1.9603
# Epoch 83/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4014 - mae: 1.3331 - val_loss: 6.8957 - val_mae: 1.9943
# Epoch 84/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8032 - mae: 1.3629 - val_loss: 6.2224 - val_mae: 1.9181
# Epoch 85/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7692 - mae: 1.3600 - val_loss: 6.6516 - val_mae: 1.9721
# Epoch 86/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2639 - mae: 1.3034 - val_loss: 6.6829 - val_mae: 2.0166
# Epoch 87/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1586 - mae: 1.4924 - val_loss: 7.5227 - val_mae: 2.0906
# Epoch 88/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6085 - mae: 1.4148 - val_loss: 6.4546 - val_mae: 1.9890
# Epoch 89/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9939 - mae: 1.3158 - val_loss: 7.7884 - val_mae: 2.1993
# Epoch 90/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9419 - mae: 1.4426 - val_loss: 6.9593 - val_mae: 2.0483
# Epoch 91/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5005 - mae: 1.5321 - val_loss: 6.2713 - val_mae: 1.8927
# Epoch 92/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3908 - mae: 1.3349 - val_loss: 6.0381 - val_mae: 1.8736
# Epoch 93/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2942 - mae: 1.2674 - val_loss: 8.1526 - val_mae: 2.1683
# Epoch 94/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7305 - mae: 1.4301 - val_loss: 6.9165 - val_mae: 2.0917
# Epoch 95/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4987 - mae: 1.4004 - val_loss: 6.5205 - val_mae: 1.9643
# Epoch 96/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8878 - mae: 1.2467 - val_loss: 5.9715 - val_mae: 1.8837
# Epoch 97/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7641 - mae: 1.2455 - val_loss: 5.8395 - val_mae: 1.8731
# Epoch 98/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5054 - mae: 1.3126 - val_loss: 6.1784 - val_mae: 1.9650
# Epoch 99/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1523 - mae: 1.2955 - val_loss: 5.8872 - val_mae: 1.8899
# Epoch 100/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9451 - mae: 1.3162 - val_loss: 8.1238 - val_mae: 2.1757
# Epoch 101/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1612 - mae: 1.2991 - val_loss: 6.0208 - val_mae: 1.9564
# Epoch 102/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9408 - mae: 1.4028 - val_loss: 5.9551 - val_mae: 1.9234
# Epoch 103/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1086 - mae: 1.2984 - val_loss: 5.8555 - val_mae: 1.8995
# Epoch 104/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3075 - mae: 1.3766 - val_loss: 6.8254 - val_mae: 1.9462
# Epoch 105/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.0077 - mae: 1.2504 - val_loss: 5.5987 - val_mae: 1.8324
# Epoch 106/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1384 - mae: 1.2790 - val_loss: 6.6531 - val_mae: 1.9309
# Epoch 107/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2363 - mae: 1.3003 - val_loss: 5.4361 - val_mae: 1.7636
# Epoch 108/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.0838 - mae: 1.2923 - val_loss: 6.8425 - val_mae: 2.0448
# Epoch 109/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8608 - mae: 1.1884 - val_loss: 6.1880 - val_mae: 1.9370
# Epoch 110/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1011 - mae: 1.0517 - val_loss: 5.8305 - val_mae: 1.8794
# Epoch 111/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4924 - mae: 1.3939 - val_loss: 6.0589 - val_mae: 1.8894
# Epoch 112/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0731 - mae: 1.2682 - val_loss: 6.7381 - val_mae: 2.0103
# Epoch 113/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9044 - mae: 1.2098 - val_loss: 6.1063 - val_mae: 1.8767
# Epoch 114/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1235 - mae: 1.3051 - val_loss: 6.1661 - val_mae: 1.9636
# Epoch 115/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6659 - mae: 1.2335 - val_loss: 6.2236 - val_mae: 1.9511
# Epoch 116/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2513 - mae: 1.0956 - val_loss: 5.9533 - val_mae: 1.8091
# Epoch 117/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9868 - mae: 1.3108 - val_loss: 6.2933 - val_mae: 1.9863
# Epoch 118/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2156 - mae: 1.3025 - val_loss: 5.7608 - val_mae: 1.8538
# Epoch 119/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7875 - mae: 1.2336 - val_loss: 6.6724 - val_mae: 1.8587
# Epoch 120/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0084 - mae: 1.2809 - val_loss: 6.0477 - val_mae: 1.9415
# Epoch 121/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8602 - mae: 1.2405 - val_loss: 5.7751 - val_mae: 1.8800
# Epoch 122/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7910 - mae: 1.2057 - val_loss: 6.7478 - val_mae: 2.0648
# Epoch 123/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4845 - mae: 1.1647 - val_loss: 5.6618 - val_mae: 1.8426
# Epoch 124/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1594 - mae: 1.2785 - val_loss: 7.4644 - val_mae: 2.1085
# Epoch 125/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1828 - mae: 1.3168 - val_loss: 6.0971 - val_mae: 1.8511
# Epoch 126/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3493 - mae: 1.0949 - val_loss: 6.0344 - val_mae: 1.9086
# Epoch 127/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4438 - mae: 1.1511 - val_loss: 6.4958 - val_mae: 1.9623
# Epoch 128/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2991 - mae: 1.1621 - val_loss: 6.0744 - val_mae: 1.8900
# Epoch 129/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7553 - mae: 1.2290 - val_loss: 6.4099 - val_mae: 1.8266
# Epoch 130/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5782 - mae: 1.2272 - val_loss: 5.4292 - val_mae: 1.7457
# Epoch 131/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0466 - mae: 1.0763 - val_loss: 6.2573 - val_mae: 2.0298
# Epoch 132/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1461 - mae: 1.0824 - val_loss: 6.8727 - val_mae: 2.1450
# Epoch 133/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9076 - mae: 1.2478 - val_loss: 5.7520 - val_mae: 1.8962
# Epoch 134/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6653 - mae: 1.1710 - val_loss: 5.6009 - val_mae: 1.7535
# Epoch 135/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2204 - mae: 1.1080 - val_loss: 5.9091 - val_mae: 1.9048
# Epoch 136/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0043 - mae: 1.0560 - val_loss: 5.8326 - val_mae: 1.8527
# Epoch 137/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3615 - mae: 1.0962 - val_loss: 6.4424 - val_mae: 2.0357
# Epoch 138/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8277 - mae: 1.2297 - val_loss: 5.8438 - val_mae: 1.9595
# Epoch 139/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9245 - mae: 1.2631 - val_loss: 6.7659 - val_mae: 2.0307
# Epoch 140/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3430 - mae: 1.1097 - val_loss: 5.8255 - val_mae: 1.9167
# Epoch 141/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8724 - mae: 1.2009 - val_loss: 5.6578 - val_mae: 1.8804
# Epoch 142/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0725 - mae: 1.0548 - val_loss: 6.2250 - val_mae: 1.8956
# Epoch 143/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4112 - mae: 1.1256 - val_loss: 6.2320 - val_mae: 1.9255
# Epoch 144/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3656 - mae: 1.0958 - val_loss: 6.2869 - val_mae: 2.0081
# Epoch 145/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8608 - mae: 1.0357 - val_loss: 6.6536 - val_mae: 1.8638
# Epoch 146/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0099 - mae: 1.3464 - val_loss: 7.0882 - val_mae: 2.0860
# Epoch 147/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1633 - mae: 1.1236 - val_loss: 5.7398 - val_mae: 1.8516
# Epoch 148/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3391 - mae: 1.1159 - val_loss: 6.0347 - val_mae: 1.9310
# Epoch 149/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9918 - mae: 1.0751 - val_loss: 6.4665 - val_mae: 2.0151
# Epoch 150/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7393 - mae: 1.1374 - val_loss: 5.4333 - val_mae: 1.7726
# Epoch 151/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6526 - mae: 0.9443 - val_loss: 5.8917 - val_mae: 1.9333
# Epoch 152/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4486 - mae: 1.0913 - val_loss: 5.9170 - val_mae: 1.9579
# Epoch 153/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1142 - mae: 1.0985 - val_loss: 6.1797 - val_mae: 1.8920
# Epoch 154/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9887 - mae: 1.0418 - val_loss: 5.5399 - val_mae: 1.8648
# Epoch 155/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4718 - mae: 1.0852 - val_loss: 5.4671 - val_mae: 1.7907
# Epoch 156/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0184 - mae: 1.0093 - val_loss: 5.0611 - val_mae: 1.7420
# Epoch 157/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1051 - mae: 1.0196 - val_loss: 6.1520 - val_mae: 1.9504
# Epoch 158/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6676 - mae: 0.9562 - val_loss: 5.8932 - val_mae: 1.8561
# Epoch 159/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0648 - mae: 1.0048 - val_loss: 6.4155 - val_mae: 1.9981
# Epoch 160/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9509 - mae: 1.0283 - val_loss: 6.0563 - val_mae: 1.9505
# Epoch 161/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1489 - mae: 1.0678 - val_loss: 6.9988 - val_mae: 1.9823
# Epoch 162/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3389 - mae: 1.1338 - val_loss: 6.4299 - val_mae: 2.0205
# Epoch 163/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5915 - mae: 0.9568 - val_loss: 6.1795 - val_mae: 1.9585
# Epoch 164/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3006 - mae: 1.0914 - val_loss: 7.5373 - val_mae: 2.2284
# Epoch 165/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9086 - mae: 1.2838 - val_loss: 5.6084 - val_mae: 1.7506
# Epoch 166/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1289 - mae: 1.0984 - val_loss: 5.5775 - val_mae: 1.8149
# Epoch 167/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8947 - mae: 1.0048 - val_loss: 5.6305 - val_mae: 1.7624
# Epoch 168/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6739 - mae: 0.9710 - val_loss: 5.8938 - val_mae: 1.8689
# Epoch 169/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8352 - mae: 0.9797 - val_loss: 5.3211 - val_mae: 1.7644
# Epoch 170/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7961 - mae: 0.9824 - val_loss: 7.0689 - val_mae: 2.0342
# Epoch 171/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6091 - mae: 1.2329 - val_loss: 5.8111 - val_mae: 1.8165
# Epoch 172/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8909 - mae: 0.9817 - val_loss: 6.4147 - val_mae: 1.9456
# Epoch 173/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3132 - mae: 1.0803 - val_loss: 5.8550 - val_mae: 1.9082
# Epoch 174/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5936 - mae: 0.9812 - val_loss: 6.1600 - val_mae: 1.9824
# Epoch 175/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5603 - mae: 0.9245 - val_loss: 5.5055 - val_mae: 1.7472
# Epoch 176/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0020 - mae: 1.0909 - val_loss: 6.1056 - val_mae: 1.9496
# Epoch 177/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9874 - mae: 1.0424 - val_loss: 5.9244 - val_mae: 1.9634
# Epoch 178/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0672 - mae: 1.0789 - val_loss: 5.3661 - val_mae: 1.8217
# Epoch 179/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9480 - mae: 1.0222 - val_loss: 6.0354 - val_mae: 1.8871
# Epoch 180/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5998 - mae: 0.9128 - val_loss: 5.6734 - val_mae: 1.8580
# Epoch 181/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4235 - mae: 0.9014 - val_loss: 5.1248 - val_mae: 1.7326
# Epoch 182/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0462 - mae: 1.0360 - val_loss: 5.4201 - val_mae: 1.8232
# Epoch 183/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6804 - mae: 0.9206 - val_loss: 5.9707 - val_mae: 1.9701
# Epoch 184/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7023 - mae: 0.9604 - val_loss: 5.9528 - val_mae: 1.9365
# Epoch 185/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7091 - mae: 0.9773 - val_loss: 6.3078 - val_mae: 1.9918
# Epoch 186/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8931 - mae: 1.0081 - val_loss: 6.4627 - val_mae: 1.9438
# Epoch 187/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8224 - mae: 1.0217 - val_loss: 6.6579 - val_mae: 1.9423
# Epoch 188/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9306 - mae: 1.0499 - val_loss: 6.5085 - val_mae: 1.9369
# Epoch 189/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9512 - mae: 1.0377 - val_loss: 5.8550 - val_mae: 1.8699
# Epoch 190/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9958 - mae: 1.0807 - val_loss: 5.4010 - val_mae: 1.8381
# Epoch 191/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4206 - mae: 1.1426 - val_loss: 6.2043 - val_mae: 2.0027
# Epoch 192/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7706 - mae: 0.9880 - val_loss: 5.4633 - val_mae: 1.8472
# Epoch 193/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7289 - mae: 0.9726 - val_loss: 5.4713 - val_mae: 1.8184
# Epoch 194/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8513 - mae: 0.9674 - val_loss: 5.9767 - val_mae: 1.8921
# Epoch 195/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8184 - mae: 1.0007 - val_loss: 5.5745 - val_mae: 1.8650
# Epoch 196/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6680 - mae: 0.9286 - val_loss: 5.5456 - val_mae: 1.7985
# Epoch 197/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7322 - mae: 0.9461 - val_loss: 5.8659 - val_mae: 1.9226
# Epoch 198/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6362 - mae: 0.9418 - val_loss: 5.8156 - val_mae: 1.9141
# Epoch 199/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4631 - mae: 0.8640 - val_loss: 5.5310 - val_mae: 1.8353
# Epoch 200/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2933 - mae: 0.8355 - val_loss: 5.5989 - val_mae: 1.8542
# Epoch 201/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4095 - mae: 0.8646 - val_loss: 6.3756 - val_mae: 1.9414
# Epoch 202/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5873 - mae: 0.9360 - val_loss: 5.2753 - val_mae: 1.8252
# Epoch 203/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6903 - mae: 0.9183 - val_loss: 5.3385 - val_mae: 1.7791
# Epoch 204/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9132 - mae: 0.9900 - val_loss: 5.6807 - val_mae: 1.8331
# Epoch 205/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2769 - mae: 1.1601 - val_loss: 5.3897 - val_mae: 1.7882
# Epoch 206/300
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7241 - mae: 0.9909 - val_loss: 5.6397 - val_mae: 1.8500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# Model Evaluation:
# MSE: 11.06444280214234
# R2 Score: 0.8670839587683096
# Model Accuracy (%): 86.70839587683096

# %% [markdown]
# # Delhi Housing Dataset

# %%
# !pip install india-housing-datasets

import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.metrics import mean_squared_error, r2_score
from india_housing_datasets import load_housing
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dense, BatchNormalization

city_name = "delhi"
df = load_housing(city_name)

for col in df.columns:
    if df[col].dtype in ['float64', 'int64']:
        df[col].fillna(df[col].mean(), inplace=True)
    else:
        df[col].fillna(df[col].mode()[0], inplace=True)

skewed_cols = ['price_lakhs', 'area_sqft']
for col in skewed_cols:
    df[col] = np.log1p(df[col])

X = df.drop("price_lakhs", axis=1)
y = df["price_lakhs"]

cat_cols = X.select_dtypes(include=['object']).columns.tolist()
num_cols = X.select_dtypes(include=['number']).columns.tolist()

preprocess = ColumnTransformer([
    ("num", StandardScaler(), num_cols),
    ("cat", OneHotEncoder(handle_unknown='ignore'), cat_cols)
])

X_processed = preprocess.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X_processed, y, test_size=0.2, random_state=42
)

model = tf.keras.Sequential([
    Dense(256, activation='relu', input_shape=(X_train.shape[1],)),
    BatchNormalization(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dense(64, activation='relu'),
    BatchNormalization(),
    Dense(32, activation='relu'),
    Dense(1)
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='mse',
    metrics=['mae']
)

early_stop = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

history = model.fit(
    X_train, y_train,
    epochs=300,
    batch_size=8,
    validation_split=0.1,
    verbose=1,
    callbacks=[early_stop]
)

y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("\nModel Evaluation")
print("MSE:", mse)
print("R2 Score:", r2)
print("Accuracy (%):", r2 * 100)

plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title("Loss vs Epochs")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['mae'], label='Train MAE')
plt.plot(history.history['val_mae'], label='Val MAE')
plt.title("MAE vs Epochs")
plt.xlabel("Epochs")
plt.ylabel("MAE")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Requirement already satisfied: india-housing-datasets in /usr/local/lib/python3.12/dist-packages (1.0.0)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from india-housing-datasets) (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->india-housing-datasets) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->india-housing-datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->india-housing-datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->india-housing-datasets) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->india-housing-datasets) (1.17.0)
# /tmp/ipython-input-1229965837.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)
# /tmp/ipython-input-1229965837.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 11.7981 - mae: 3.1615 - val_loss: 19.8657 - val_mae: 4.2475
# Epoch 2/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.3901 - mae: 0.9143 - val_loss: 10.8424 - val_mae: 3.0065
# Epoch 3/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.6780 - mae: 0.6553 - val_loss: 5.8449 - val_mae: 2.0383
# Epoch 4/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5344 - mae: 0.5712 - val_loss: 2.9230 - val_mae: 1.2847
# Epoch 5/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.4785 - mae: 0.5491 - val_loss: 1.7021 - val_mae: 0.9436
# Epoch 6/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.4843 - mae: 0.5650 - val_loss: 1.2922 - val_mae: 0.7701
# Epoch 7/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4354 - mae: 0.5256 - val_loss: 0.8532 - val_mae: 0.6329
# Epoch 8/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3749 - mae: 0.4866 - val_loss: 0.5406 - val_mae: 0.5065
# Epoch 9/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3922 - mae: 0.4928 - val_loss: 0.4969 - val_mae: 0.5491
# Epoch 10/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3561 - mae: 0.4617 - val_loss: 0.4683 - val_mae: 0.5315
# Epoch 11/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3519 - mae: 0.4551 - val_loss: 0.2539 - val_mae: 0.4083
# Epoch 12/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2634 - mae: 0.4151 - val_loss: 0.4670 - val_mae: 0.4907
# Epoch 13/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2658 - mae: 0.4072 - val_loss: 0.3350 - val_mae: 0.4542
# Epoch 14/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2654 - mae: 0.4051 - val_loss: 0.7598 - val_mae: 0.6672
# Epoch 15/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.3231 - mae: 0.4003 - val_loss: 0.3127 - val_mae: 0.4549
# Epoch 16/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2682 - mae: 0.4093 - val_loss: 0.2319 - val_mae: 0.3966
# Epoch 17/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3081 - mae: 0.4383 - val_loss: 0.2186 - val_mae: 0.3750
# Epoch 18/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2184 - mae: 0.3652 - val_loss: 0.2656 - val_mae: 0.4136
# Epoch 19/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2592 - mae: 0.3978 - val_loss: 0.2514 - val_mae: 0.4336
# Epoch 20/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1544 - mae: 0.3087 - val_loss: 0.2211 - val_mae: 0.3997
# Epoch 21/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1879 - mae: 0.3412 - val_loss: 0.5262 - val_mae: 0.5801
# Epoch 22/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2039 - mae: 0.3614 - val_loss: 0.2828 - val_mae: 0.4258
# Epoch 23/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2761 - mae: 0.4026 - val_loss: 0.2159 - val_mae: 0.3771
# Epoch 24/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2150 - mae: 0.3612 - val_loss: 0.2888 - val_mae: 0.4491
# Epoch 25/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1620 - mae: 0.3262 - val_loss: 0.2814 - val_mae: 0.4214
# Epoch 26/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1908 - mae: 0.3402 - val_loss: 0.3117 - val_mae: 0.4565
# Epoch 27/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1589 - mae: 0.3204 - val_loss: 0.2321 - val_mae: 0.3804
# Epoch 28/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1477 - mae: 0.2968 - val_loss: 0.2954 - val_mae: 0.4241
# Epoch 29/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.2023 - mae: 0.3481 - val_loss: 0.3103 - val_mae: 0.4563
# Epoch 30/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.1548 - mae: 0.3145 - val_loss: 0.2145 - val_mae: 0.3734
# Epoch 31/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1674 - mae: 0.3194 - val_loss: 0.3086 - val_mae: 0.4401
# Epoch 32/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1672 - mae: 0.3239 - val_loss: 0.2478 - val_mae: 0.3879
# Epoch 33/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1631 - mae: 0.3283 - val_loss: 0.2389 - val_mae: 0.3902
# Epoch 34/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.1525 - mae: 0.3036 - val_loss: 0.2596 - val_mae: 0.3999
# Epoch 35/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2174 - mae: 0.3591 - val_loss: 0.3753 - val_mae: 0.4508
# Epoch 36/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1436 - mae: 0.3044 - val_loss: 0.3749 - val_mae: 0.4493
# Epoch 37/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1799 - mae: 0.3195 - val_loss: 0.2348 - val_mae: 0.3859
# Epoch 38/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1317 - mae: 0.2860 - val_loss: 0.2548 - val_mae: 0.4071
# Epoch 39/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1785 - mae: 0.3187 - val_loss: 0.1682 - val_mae: 0.3366
# Epoch 40/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1605 - mae: 0.3054 - val_loss: 0.1889 - val_mae: 0.3583
# Epoch 41/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1156 - mae: 0.2715 - val_loss: 0.1655 - val_mae: 0.3255
# Epoch 42/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1367 - mae: 0.2964 - val_loss: 0.2281 - val_mae: 0.3835
# Epoch 43/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1408 - mae: 0.3024 - val_loss: 0.2747 - val_mae: 0.3971
# Epoch 44/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.1433 - mae: 0.2959 - val_loss: 0.2091 - val_mae: 0.3491
# Epoch 45/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1545 - mae: 0.3136 - val_loss: 0.3120 - val_mae: 0.4302
# Epoch 46/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1321 - mae: 0.2916 - val_loss: 0.1999 - val_mae: 0.3595
# Epoch 47/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1179 - mae: 0.2719 - val_loss: 0.1648 - val_mae: 0.3344
# Epoch 48/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1637 - mae: 0.3081 - val_loss: 0.3221 - val_mae: 0.4353
# Epoch 49/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1369 - mae: 0.2884 - val_loss: 0.1491 - val_mae: 0.3060
# Epoch 50/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1353 - mae: 0.2838 - val_loss: 0.3051 - val_mae: 0.4339
# Epoch 51/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.1197 - mae: 0.2723 - val_loss: 0.2786 - val_mae: 0.4079
# Epoch 52/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1294 - mae: 0.2748 - val_loss: 0.1236 - val_mae: 0.2656
# Epoch 53/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1178 - mae: 0.2628 - val_loss: 0.1501 - val_mae: 0.3197
# Epoch 54/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1135 - mae: 0.2709 - val_loss: 0.2125 - val_mae: 0.3755
# Epoch 55/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1160 - mae: 0.2718 - val_loss: 0.2465 - val_mae: 0.3876
# Epoch 56/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0868 - mae: 0.2287 - val_loss: 0.1385 - val_mae: 0.3035
# Epoch 57/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0876 - mae: 0.2330 - val_loss: 0.3367 - val_mae: 0.4660
# Epoch 58/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0944 - mae: 0.2374 - val_loss: 0.1841 - val_mae: 0.3449
# Epoch 59/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1164 - mae: 0.2654 - val_loss: 0.2032 - val_mae: 0.3504
# Epoch 60/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1125 - mae: 0.2632 - val_loss: 0.1537 - val_mae: 0.3157
# Epoch 61/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1130 - mae: 0.2641 - val_loss: 0.1656 - val_mae: 0.3329
# Epoch 62/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1148 - mae: 0.2662 - val_loss: 0.1274 - val_mae: 0.2797
# Epoch 63/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1083 - mae: 0.2625 - val_loss: 0.1977 - val_mae: 0.3411
# Epoch 64/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1262 - mae: 0.2704 - val_loss: 0.1995 - val_mae: 0.3578
# Epoch 65/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1560 - mae: 0.3185 - val_loss: 0.2156 - val_mae: 0.3877
# Epoch 66/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1018 - mae: 0.2533 - val_loss: 0.1846 - val_mae: 0.3438
# Epoch 67/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1328 - mae: 0.2752 - val_loss: 0.1200 - val_mae: 0.2936
# Epoch 68/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1095 - mae: 0.2612 - val_loss: 0.1236 - val_mae: 0.2587
# Epoch 69/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1234 - mae: 0.2781 - val_loss: 0.1455 - val_mae: 0.3019
# Epoch 70/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1049 - mae: 0.2641 - val_loss: 0.2283 - val_mae: 0.3629
# Epoch 71/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0982 - mae: 0.2470 - val_loss: 0.1255 - val_mae: 0.2765
# Epoch 72/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0644 - mae: 0.2033 - val_loss: 0.1054 - val_mae: 0.2547
# Epoch 73/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1005 - mae: 0.2487 - val_loss: 0.2286 - val_mae: 0.3620
# Epoch 74/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0878 - mae: 0.2416 - val_loss: 0.1678 - val_mae: 0.3452
# Epoch 75/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0897 - mae: 0.2506 - val_loss: 0.1126 - val_mae: 0.2804
# Epoch 76/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0868 - mae: 0.2306 - val_loss: 0.1544 - val_mae: 0.3291
# Epoch 77/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0747 - mae: 0.2091 - val_loss: 0.1400 - val_mae: 0.3174
# Epoch 78/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0982 - mae: 0.2484 - val_loss: 0.1185 - val_mae: 0.2897
# Epoch 79/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0919 - mae: 0.2438 - val_loss: 0.1281 - val_mae: 0.2898
# Epoch 80/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0782 - mae: 0.2200 - val_loss: 0.1339 - val_mae: 0.2950
# Epoch 81/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1185 - mae: 0.2653 - val_loss: 0.1615 - val_mae: 0.3203
# Epoch 82/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0756 - mae: 0.2168 - val_loss: 0.1163 - val_mae: 0.2684
# Epoch 83/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0778 - mae: 0.2259 - val_loss: 0.1395 - val_mae: 0.2983
# Epoch 84/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0808 - mae: 0.2300 - val_loss: 0.1849 - val_mae: 0.3378
# Epoch 85/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0826 - mae: 0.2202 - val_loss: 0.1666 - val_mae: 0.3224
# Epoch 86/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0915 - mae: 0.2320 - val_loss: 0.1318 - val_mae: 0.3144
# Epoch 87/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0654 - mae: 0.2018 - val_loss: 0.1175 - val_mae: 0.2875
# Epoch 88/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0651 - mae: 0.2028 - val_loss: 0.1523 - val_mae: 0.3029
# Epoch 89/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0821 - mae: 0.2322 - val_loss: 0.1446 - val_mae: 0.3272
# Epoch 90/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0891 - mae: 0.2317 - val_loss: 0.1518 - val_mae: 0.2992
# Epoch 91/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0880 - mae: 0.2296 - val_loss: 0.1190 - val_mae: 0.2833
# Epoch 92/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0872 - mae: 0.2338 - val_loss: 0.1107 - val_mae: 0.2858
# Epoch 93/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0883 - mae: 0.2410 - val_loss: 0.2016 - val_mae: 0.3535
# Epoch 94/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0731 - mae: 0.2162 - val_loss: 0.1115 - val_mae: 0.2743
# Epoch 95/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0814 - mae: 0.2274 - val_loss: 0.1565 - val_mae: 0.2965
# Epoch 96/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0695 - mae: 0.2093 - val_loss: 0.1187 - val_mae: 0.2699
# Epoch 97/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0874 - mae: 0.2365 - val_loss: 0.2125 - val_mae: 0.3772
# Epoch 98/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0786 - mae: 0.2200 - val_loss: 0.2676 - val_mae: 0.4200
# Epoch 99/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0824 - mae: 0.2177 - val_loss: 0.2541 - val_mae: 0.4215
# Epoch 100/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0744 - mae: 0.2175 - val_loss: 0.1520 - val_mae: 0.3107
# Epoch 101/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0650 - mae: 0.2029 - val_loss: 0.1270 - val_mae: 0.2901
# Epoch 102/300
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0736 - mae: 0.2136 - val_loss: 0.1459 - val_mae: 0.3230
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#
# Model Evaluation
# MSE: 0.18076277490091497
# R2 Score: 0.9016279017726572
# Accuracy (%): 90.16279017726572
